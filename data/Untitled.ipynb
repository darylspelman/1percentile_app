# %%
import pandas as pd

# %%
df = pd.read_pickle('business_quality_data.pkl')

# %%
df.columns
# Out:
# Index(['name', 'mar_cap_mUSD', '3m_val_turnover_mUSD', 'country_name',
#        'exchange1', 'sector', 'industry', 'primary', 'reporting_currency',
#        'reporting_currency', 'BQ_score', 'BQ_score_percentile', 'EQ_score',
#        'EQ_score_percentile', 'govern_score', 'govern_score_percentile',
#        'V_score', 'V_score_percentile', 'BQ_score_annual_0y',
#        'BQ_score_annual_0y_pctile', 'BQ_score_annual_-1y',
#        'BQ_score_annual_-1y_pctile', 'BQ_score_annual_-2y',
#        'BQ_score_annual_-2y_pctile', 'BQ_score_chg_0y',
#        'BQ_score_chg_0y_pctile', 'BQ_RoC_score_percentile',
#        'BQ_growth_score_percentile', 'BQ_profitability_score_percentile',
#        'BQ_asset_intensity_score_percentile',
#        'BQ_capital_structure_score_percentile',
#        'BQ_reinvestment_score_percentile', 'BQ_shareholder_score_percentile',
#        'EQ_accruals_comp_score_percentile',
#        'EQ_assumption_comp_score_percentile', 'EQ_risk_comp_score_percentile',
#        'EQ_compound_comp_score_percentile', 'V_score_fundamental_percentile',
#        'V_score_relative_percentile',
#        'Alignement with Shareholders_percentile', 'Board Quality_percentile',
#        'Committee Quality_percentile', 'ROE', 'median ROE 3-yr', 'ROE_change',
#        'ROA', 'RNOA', 'ROIC', 'assets/equity', 'assets/equity_change', 'GPM%',
#        'OPMargin', 'PM', 'median PM 3-yr', 'PM_change', 'OPM_change',
#        'SGA_pctSales', 'Revenue 1-yr CAGR', 'ShareholderEquity 1-yr CAGR',
#        'Revenue 3-yr CAGR', 'ShareholderEquity 3-yr CAGR', 'Share growth',
#        'div_payout_rate', 'sales/assets', 'sales/asset_change',
#        'Sales/avg_NOA', 'days_CCC', 'days_CCC_change', 'R&D_pctSales',
#        'days_sales_outstanding', 'days_inventory_outstanding',
#        'days_payables_outstanding', 'net_debt/equity', 'sloan_accruals_assets',
#        'CFO%sales', 'avg_PPE_life', 'FCF%sales',
#        'intangibleAssets/totalAssets', 'CFO_NI', 'S&M%sales',
#        'total_investment/sales', 'capitalExpenditures_pctSales', 'P/E_ttm',
#        'P/B', 'P/S_ttm', 'EV/EBIT_ttm', 'EV/EBITDA_ttm'],
#       dtype='object')

# %%
df_out = df[['BQ_score', 'BQ_score_percentile','V_score', 'V_score_percentile', 'BQ_RoC_score_percentile',
       'BQ_growth_score_percentile', 'BQ_profitability_score_percentile',
       'BQ_asset_intensity_score_percentile',
       'BQ_capital_structure_score_percentile',
       'BQ_reinvestment_score_percentile', 'BQ_shareholder_score_percentile']]

# %%
df_out
# Out:
#            BQ_score  BQ_score_percentile  V_score  V_score_percentile  \
# RTL.VI        105.3                0.544 -210.442               0.101
# TSMC34.SA     415.5                0.996   68.437               0.543
# MSF0.F        393.9                0.993 -103.362               0.298
# MSFT.MX       393.9                0.993 -209.861               0.101
# MSFT          393.9                0.993 -115.129               0.281
# ...             ...                  ...      ...                 ...
# SYSX           60.3                0.426  134.431               0.637
# ILLA.MI       -68.9                0.156   79.800               0.558
# ALADO.PA     -201.6                0.037  364.403               0.920
# TMBRQ        -178.7                0.050  334.916               0.893
# TOSYY          97.8                0.522  532.478               0.992
#
#            BQ_RoC_score_percentile  BQ_growth_score_percentile  \
# RTL.VI                       0.688                       0.302
# TSMC34.SA                    0.920                       0.873
# MSF0.F                       0.965                       0.918
# MSFT.MX                      0.965                       0.918
# MSFT                         0.965                       0.918
# ...                            ...                         ...
# SYSX                         0.749                       0.780
# ILLA.MI                      0.287                       0.317
# ALADO.PA                     0.159                       0.290
# TMBRQ                        0.063                       0.043
# TOSYY                        0.521                       0.484
#
#            BQ_profitability_score_percentile  \
# RTL.VI                                 0.480
# TSMC34.SA                              0.997
# MSF0.F                                 0.967
# MSFT.MX                                0.967
# MSFT                                   0.967
# ...                                      ...
# SYSX                                   0.438
# ILLA.MI                                0.241
# ALADO.PA                               0.015
# TMBRQ                                  0.241
# TOSYY                                  0.490
#
#            BQ_asset_intensity_score_percentile  \
# RTL.VI                                   0.683
# TSMC34.SA                                0.820
# MSF0.F                                   0.690
# MSFT.MX                                  0.690
# MSFT                                     0.690
# ...                                        ...
# SYSX                                     0.684
# ILLA.MI                                  0.855
# ALADO.PA                                 0.369
# TMBRQ                                    0.314
# TOSYY                                    0.507
#
#            BQ_capital_structure_score_percentile  \
# RTL.VI                                     0.625
# TSMC34.SA                                  0.665
# MSF0.F                                     0.754
# MSFT.MX                                    0.754
# MSFT                                       0.754
# ...                                          ...
# SYSX                                       0.126
# ILLA.MI                                    0.026
# ALADO.PA                                   0.930
# TMBRQ                                      0.797
# TOSYY                                      0.320
#
#            BQ_reinvestment_score_percentile  BQ_shareholder_score_percentile
# RTL.VI                                0.438                            0.638
# TSMC34.SA                             0.973                            0.918
# MSF0.F                                0.918                            0.944
# MSFT.MX                               0.918                            0.944
# MSFT                                  0.918                            0.944
# ...                                     ...                              ...
# SYSX                                  0.438                            0.071
# ILLA.MI                               0.438                            0.071
# ALADO.PA                              0.438                            0.071
# TMBRQ                                 0.438                            0.071
# TOSYY                                 0.438                            0.638
#
# [41063 rows x 11 columns]

# %%
df_out = df_out[~df_out.index.str.contains('\.')]

# %%
df_out.to_csv('percentile_scores.csv')

# %%
curr = pd.read_pickle("./currency_scrape.pkl")

# %%
curr
# Out:
#           reporting_currency trade_currency   exchange
# Symbol
# TSMC34.SA                BRL            BRL  São Paulo
# MSFT.MX                  MXN            MXN     Mexico
# MSF.F                    EUR            EUR  Frankfurt
# MSFT.VI                  EUR            EUR     Vienna
# MSF.DE                   EUR            EUR      XETRA
# ...                      ...            ...        ...
# TOSYY                    USD            USD  Other OTC
# PEHD                     USD            USD  Other OTC
# YUKA                     USD            USD  Other OTC
# MDCE                     USD            USD  Other OTC
# GVDI                     USD            USD  Other OTC
#
# [59384 rows x 3 columns]

# %%
comp_info = pd.read_pickle("./company_info_short.pkl")

# %%
comp_info
# Out:
#                                                            name  \
# Symbol
# TSMC34.SA     Taiwan Semiconductor Manufacturing Company Lim...
# MSFT.MX                                   Microsoft Corporation
# MSF.F                                     Microsoft Corporation
# MSF.DE                                    Microsoft Corporation
# MSFT                                      Microsoft Corporation
# ...                                                         ...
# 2721.T                                         J-Holdings Corp.
# ATLAS.IS          Atlas Menkul Kiymetler Yatirim Ortakligi A.S.
# MALUPAPER.NS                           Malu Paper Mills Limited
# 227950.KQ                                        N2Tech Co.,Ltd
# BTTX                                  Better Therapeutics, Inc.
#
#                      sector_comb              industry_comb   country_name  \
# Symbol
# TSMC34.SA             Technology             Semiconductors         Brazil
# MSFT.MX               Technology  Software - Infrastructure         Mexico
# MSF.F                 Technology  Software - Infrastructure          Japan
# MSF.DE                Technology  Software - Infrastructure        Germany
# MSFT                  Technology  Software - Infrastructure  United States
# ...                          ...                        ...            ...
# 2721.T               Real Estate       Real Estate Services          Japan
# ATLAS.IS      Financial Services            Capital Markets         Turkey
# MALUPAPER.NS     Basic Materials     Paper & Paper Products          India
# 227950.KQ                   None                       None    South Korea
# BTTX                  Healthcare              Biotechnology  United States
#
#               mar_cap_mUSD  3m_val_turnover_mUSD primary
# Symbol
# TSMC34.SA     3.488470e+06              0.334546       N
# MSFT.MX       3.088376e+06              2.008184       S
# MSF.F         3.088061e+06              2.114259       S
# MSF.DE        3.088061e+06             13.463041       S
# MSFT          3.087000e+06          10121.164500       Y
# ...                    ...                   ...     ...
# 2721.T        1.004031e+01              0.211604       Y
# ATLAS.IS      1.003216e+01              0.183254       Y
# MALUPAPER.NS  1.002598e+01              0.138419       Y
# 227950.KQ     1.000449e+01              0.584429       Y
# BTTX          1.000400e+01              0.405351       Y
#
# [28378 rows x 7 columns]
